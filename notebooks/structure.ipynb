# %%
import os

dossiers = [
    "data/raw",
    "data/processed",
    "notebooks",
    "src"
]

for dossier in dossiers:
    os.makedirs(dossier, exist_ok=True)

with open("requirements.txt", "w") as f:
    f.write("yfinance\npandas\nnumpy\n")
