# %%
import os
import sys
from pathlib import Path

PROJET = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJET) not in sys.path:
    sys.path.append(str(PROJET))

# Définis d'abord ta vraie clé API OpenAI dans l'environnement.
# Exemple PowerShell : $env:OPENAI_API_KEY = "sk-..."
if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("OPENAI_API_KEY n'est pas définie.")

from src.portfolio_chatbot import run_demo

question = (
    "Bonjour, je cherche à investir sur la Bourse de Casablanca "
    "avec un rendement de 12% et un risque maximum de 18%."
)

print(run_demo(question))
